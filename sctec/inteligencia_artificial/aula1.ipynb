# %% [markdown]
# #### Assuntos
# 1. IA vs Programação
# IA descobre regras dos dados. Programação segue regras humanas
#
# 2. Anatomia de Projetos
# Dados -> infraestrutura -> Estatística -> Modelos -> Ética.
#
# 3. Ferramentas
# Pandas, NumPy, Seaborn, Matplotlib e Scikit-learn
#
# #### Exploração inicial
# - Carregar CSV
# - inspecionar com:
# 	- .head()
# 	- .info()
# 	- .describe()

# %%
import pandas as pd
import numpy as np

# To read the dataset
df = pd.read_csv("dataset/ncr_ride_bookings.csv")

# %%
# To get only the head of the dataset
print(df.head())

# %%
# To get the size of the dataset
df.shape

# %%
# To get the types of datasets
df.dtypes

# %%
# To get statistical information from the dataset
df.describe()

#Attention: df.describe is another different method from df.describe()

# %%
# To get the null itens (with the sum as method chaining)
df.isnull().sum()

# %%
# To get specific values and then removing all null and bring the values.
len(df["Booking Value"].dropna().values)

# %%
df["Booking Value"].mode()[0]

# %%
df["Booking Value"].mean()

# %%
#standard deviation
df["Booking Value"].std()

# %%
df["Booking Value"].var()

# %%
#This already show mean, std, etc.
df["Booking Value"].describe()

# %%
#Bar graphic
